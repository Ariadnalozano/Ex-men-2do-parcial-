# %% [markdown]
# ##L0S MEJORES Y PEORES LUGARES PARA VIVIR
#
#
#
# En la actualidad, ha surgido una pregunta constante: ¿Cuál es el mejor lugar para vivir? Sabemos que la contaminación esta a tope, que la inseguridad es muy grave, que hay desempleo y crisis económica, pero al final existen ciertos paises que han logrado superar estos obstáculos y se han convertido en los top 10 mejores países en 3 contextos diferentes:
# 1. Social health
# 2. Environmental health
# 3. Economic health
# 4. General Análisis

# %%
import pandas as pd

# %%
data = pd.read_csv ("GreenCities-Data.csv")
data
# Out:
#          city  People  Planet  Profit  Overall      Country Continent
# 0      Zurich      27       1       5        1  Switzerland    Europe
# 1   Singapore      48      12       1        2    Singapore      Asia
# 2   Stockholm      14       2      10        3       Sweden    Europe
# 3      Vienna       4       4      14        4      Austria    Europe
# 4      London      37       9       3        5         U.K.    Europe
# ..        ...     ...     ...     ...      ...          ...       ...
# 95     Manila      94      86      91       96  Philippines      Asia
# 96  New Delhi      87      90      96       97        India      Asia
# 97    Nairobi      98      83      90       98        Kenya    Africa
# 98      Cairo      92      93      98       99        Egypt    Africa
# 99    Kolkata      78     100     100      100        India      Asia
#
# [100 rows x 7 columns]

# %%
#Cuantos renglones y cuantas columnas existe en la matriz
data.shape
# Out:
# (100, 7)

# %%
data.ndim #Dimension como objeto
# Out:
# 2

# %%
#resumen de la base
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   city       100 non-null    object
#  1   People     100 non-null    int64
#  2   Planet     100 non-null    int64
#  3   Profit     100 non-null    int64
#  4   Overall    100 non-null    int64
#  5   Country    100 non-null    object
#  6   Continent  100 non-null    object
# dtypes: int64(4), object(3)
# memory usage: 5.6+ KB

# %%
data.describe()#estadistica descriptiva
# Out:
#            People      Planet      Profit     Overall
# count  100.000000  100.000000  100.000000  100.000000
# mean    50.500000   50.500000   50.500000   50.500000
# std     29.011492   29.011492   29.011492   29.011492
# min      1.000000    1.000000    1.000000    1.000000
# 25%     25.750000   25.750000   25.750000   25.750000
# 50%     50.500000   50.500000   50.500000   50.500000
# 75%     75.250000   75.250000   75.250000   75.250000
# max    100.000000  100.000000  100.000000  100.000000

# %% [markdown]
# ##Slice

# %%
data["Planet"]
# Out:
# 0       1
# 1      12
# 2       2
# 3       4
# 4       9
#      ...
# 95     86
# 96     90
# 97     83
# 98     93
# 99    100
# Name: Planet, Length: 100, dtype: int64

# %%
data[["People", "Planet", "Profit"]]
# Out:
#     People  Planet  Profit
# 0       27       1       5
# 1       48      12       1
# 2       14       2      10
# 3        4       4      14
# 4       37       9       3
# ..     ...     ...     ...
# 95      94      86      91
# 96      87      90      96
# 97      98      83      90
# 98      92      93      98
# 99      78     100     100
#
# [100 rows x 3 columns]

# %%
data.head()
# Out:
#         city  People  Planet  Profit  Overall      Country Continent
# 0     Zurich      27       1       5        1  Switzerland    Europe
# 1  Singapore      48      12       1        2    Singapore      Asia
# 2  Stockholm      14       2      10        3       Sweden    Europe
# 3     Vienna       4       4      14        4      Austria    Europe
# 4     London      37       9       3        5         U.K.    Europe

# %%
data.head(10)
# Out:
#         city  People  Planet  Profit  Overall      Country Continent
# 0     Zurich      27       1       5        1  Switzerland    Europe
# 1  Singapore      48      12       1        2    Singapore      Asia
# 2  Stockholm      14       2      10        3       Sweden    Europe
# 3     Vienna       4       4      14        4      Austria    Europe
# 4     London      37       9       3        5         U.K.    Europe
# 5  Frankfurt      16       5      23        6      Germany    Europe
# 6      Seoul       1      26      18        7  South Korea      Asia
# 7    Hamburg       3      10      25        8      Germany    Europe
# 8     Prague       6      31       7        9      Czechia    Europe
# 9     Munich       8      24      11       10      Germany    Europe

# %%
#por renglones: Método X.iloc[índice al que queremos ingresar]

# %%
data.iloc[1]
# Out:
# city         Singapore
# People              48
# Planet              12
# Profit               1
# Overall              2
# Country      Singapore
# Continent         Asia
# Name: 1, dtype: object

# %%
data.iloc[0:5]
# Out:
#         city  People  Planet  Profit  Overall      Country Continent
# 0     Zurich      27       1       5        1  Switzerland    Europe
# 1  Singapore      48      12       1        2    Singapore      Asia
# 2  Stockholm      14       2      10        3       Sweden    Europe
# 3     Vienna       4       4      14        4      Austria    Europe
# 4     London      37       9       3        5         U.K.    Europe

# %% [markdown]
# # Ejercicios 1
#
# - Realiza un análisis descriptivo de tu base de datos.
#
# - ¿Qué tipo de análisis estadístico deseas analizar?
#
# - Enumera los distintos tipos de objetos que hay en tu base de datos: ¿qué columnas contienen datos numéricos? ¿qué columnas contienen datos categóricos?
#
# - Toma una columna que tenga datos **no nulos** numéricos y da una descripción estadística.
#
# - Elige dos columnas que contengan datos numéricos. A partir de esta subbase de datos, elige los primeros 20 elementos. Realiza nuevamente un análisis descriptivo de esta nueva subbase (escribe brevemente la importancia de tu elección).
#
# - La siguiente celda contiene un ejemplo de cómo realizar un *boxplot*. ¿Qué representa este tipo de gráficas? Realiza una gráfica *boxplot* con la subbase del punto anterior.
#
# - Finalmente, comparte tus conclusiones y tu colab.

# %% [markdown]
# Análisis descriptivo:
# En este ejercicio buscamos clasificar nuestra base de datos de modo que nos mostrara cúales eran las ciudades con clasificación más alta en los 3 parámetros a considerar; Salud social, sustntabilidad e ingreso.
# El universo es de 100 ciudades de todos los con

# %%
#descripción de la data
data.describe()
# Out:
#            People      Planet      Profit     Overall
# count  100.000000  100.000000  100.000000  100.000000
# mean    50.500000   50.500000   50.500000   50.500000
# std     29.011492   29.011492   29.011492   29.011492
# min      1.000000    1.000000    1.000000    1.000000
# 25%     25.750000   25.750000   25.750000   25.750000
# 50%     50.500000   50.500000   50.500000   50.500000
# 75%     75.250000   75.250000   75.250000   75.250000
# max    100.000000  100.000000  100.000000  100.000000

# %% [markdown]
# ¿Que tipo de analisis estadistico deseas realizar?

# %% [markdown]
# El análisis que queremos realizar es un análisis descriptivo, ya que buscamos describir los TOP en las categorías mencionadas y describir la información obtenida en los filtros que realizamos.

# %%
#Tipos de datos
type(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   city       100 non-null    object
#  1   People     100 non-null    int64
#  2   Planet     100 non-null    int64
#  3   Profit     100 non-null    int64
#  4   Overall    100 non-null    int64
#  5   Country    100 non-null    object
#  6   Continent  100 non-null    object
# dtypes: int64(4), object(3)
# memory usage: 5.6+ KB
# NoneType

# %% [markdown]
# Las columnas que contienen datos numericos son: People, Planet, Profit, Overall.
#
# Los datos categoricos se encuentran dentro de:
# City, Country y Continent

# %%
data[["People", "Continent"]]
# Out:
#     People Continent
# 0       27    Europe
# 1       48      Asia
# 2       14    Europe
# 3        4    Europe
# 4       37    Europe
# ..     ...       ...
# 95      94      Asia
# 96      87      Asia
# 97      98    Africa
# 98      92    Africa
# 99      78      Asia
#
# [100 rows x 2 columns]

# %% [markdown]
# Descripción: De los 100 países considerados, la base de datos los ordena de 1 a 100 dependiendo de la posición que se encuentra la ciudad. Para este análisis tomamos la columna de "People" que refiere a la salud social.
# En esta columna, enfocándonos en los 25 primeros lugares encontramos que:
# - El 72% de las ciudades se encuentran en Europa
# - El 8% en Norte América
# - Y sólo el 4% respectivamente en Asia y en Oriente medio.

# %%
a= data["Overall"]
a
# Out:
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
#      ...
# 95     96
# 96     97
# 97     98
# 98     99
# 99    100
# Name: Overall, Length: 100, dtype: int64

# %%
import seaborn as sns
sns.displot(a)

# %%
#subbase de las ganacias economicas y salud social
dinero_sust=(data[['Profit','People','city']])

# %%
df = dinero_sust.head(20)
df
# Out:
#     Profit  People        city
# 0        5      27      Zurich
# 1        1      48   Singapore
# 2       10      14   Stockholm
# 3       14       4      Vienna
# 4        3      37      London
# 5       23      16   Frankfurt
# 6       18       1       Seoul
# 7       25       3     Hamburg
# 8        7       6      Prague
# 9       11       8      Munich
# 10      16       7   Amsterdam
# 11      42      30      Geneva
# 12       6      38   Edinburgh
# 13      17      24  Copenhagen
# 14       9      20       Paris
# 15       2      81   Hong Kong
# 16      32       5      Berlin
# 17      20      17    Canberra
# 18      46       2   Rotterdam
# 19      34      18      Madrid

# %% [markdown]
# Analisis descriptivo:
# Esta sub-base nos da sólo dos indicadores que son Salud social y Salud económica, eliminamos la sustentabilidad y encontramos después de sacar el promedio de posición que entre estos dos parámentos tenemos a las siguientes ciudades en el TOP5:
# 1. Zurich (Profit: 5, People: 27)
# 2. Singapore (Profit: 1, People: 48)
# 3. Stockholm (Profit: 10, People: 14)
# 4. Vienna (Profit: 4, People: 14)
# 5. London (Profit: 3, People: 37)
#
# Importancia de su elección:
# La salud económica de un país suele considerarse un indicador importante en la calidad de vida de las personas, aunque creemos que la sustentabilidad juega un papel fundamental en la salud social, el objetivo de esta sub-base era comprobar la hipótesis de que los paises con mayor salud económica también tenían una posición alta en la salud social.
# El resultado arrojó valores distintos, ya que ninguno de los paises entre los top 5 económicamente hablando se encuentran en los 10 primeros lugares de salud social.

# %%
import numpy as np
boxplt = df.boxplot()

# %%
df[]
# Out:
#   File "<ipython-input-24-71f11347ebfc>", line 1
#     df[]
#        ^
# SyntaxError: invalid syntax

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ¿Que representan este tipo de graficas?
# - Resumen en cinco medidadas descriptivas
# - Permite identificar valores atipicos
# - Saber como se distribuyen los valores, identificando facilmente los atipicos.
# - Identificar mediana

# %% [markdown]
# Conclusiones:

# %% [markdown]
# Después de analizar nuestra base de datos, relacionar los 3 parámetros utilizados para medir, analizarlos individualmente y por filas específicas llegamos a la conclusión de que:
# - Aunque los 3 indicadores tienen relación entre sí, no necesariamente se encuentran en los mismos niveles de posición
# - Los países con mayores puntuaciones generalmente son más ecológicos, y buscan constantemente mejorar en técnicas de sustentabilidad
# - La sustentabilidad es el factor más importante en esta tabla ya que de sus puntuaciones se relacionan las demás posiciones
# - Las mejores ciudades para vivir se encuentran mayormente en Europa y las peores en Asia
